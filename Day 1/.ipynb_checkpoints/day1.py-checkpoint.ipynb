# %%
with open("input.txt", "r") as fp: #fp = file pointer. syntax for opening a file point to read a file. with is a scope
    for i, line in enumerate(fp):
        print(f"{i}: {line}")
# Out:
# 0: 1977
#
# 1: 1802
#
# 2: 1856
#
# 3: 1309
#
# 4: 2003
#
# 5: 1854
#
# 6: 1898
#
# 7: 1862
#
# 8: 1857
#
# 9: 542
#
# 10: 1616
#
# 11: 1599
#
# 12: 1628
#
# 13: 1511
#
# 14: 1848
#
# 15: 1623
#
# 16: 1959
#
# 17: 1693
#
# 18: 1444
#
# 19: 1211
#
# 20: 1551
#
# 21: 1399
#
# 22: 1855
#
# 23: 1538
#
# 24: 1869
#
# 25: 1664
#
# 26: 1719
#
# 27: 1241
#
# 28: 1875
#
# 29: 1733
#
# 30: 1547
#
# 31: 1813
#
# 32: 1531
#
# 33: 1773
#
# 34: 624
#
# 35: 1336
#
# 36: 1897
#
# 37: 1179
#
# 38: 1258
#
# 39: 1205
#
# 40: 1727
#
# 41: 1364
#
# 42: 1957
#
# 43: 540
#
# 44: 1970
#
# 45: 1273
#
# 46: 1621
#
# 47: 1964
#
# 48: 1723
#
# 49: 1699
#
# 50: 1847
#
# 51: 1249
#
# 52: 1254
#
# 53: 1644
#
# 54: 1449
#
# 55: 1794
#
# 56: 1797
#
# 57: 1713
#
# 58: 1534
#
# 59: 1202
#
# 60: 1951
#
# 61: 1598
#
# 62: 1926
#
# 63: 1865
#
# 64: 1294
#
# 65: 1893
#
# 66: 1641
#
# 67: 1325
#
# 68: 1432
#
# 69: 1960
#
# 70: 413
#
# 71: 1517
#
# 72: 1724
#
# 73: 1715
#
# 74: 1458
#
# 75: 1775
#
# 76: 1317
#
# 77: 1694
#
# 78: 1484
#
# 79: 1840
#
# 80: 1999
#
# 81: 1811
#
# 82: 1578
#
# 83: 1658
#
# 84: 1906
#
# 85: 1481
#
# 86: 1313
#
# 87: 1997
#
# 88: 1339
#
# 89: 1592
#
# 90: 1971
#
# 91: 1453
#
# 92: 1706
#
# 93: 1884
#
# 94: 1956
#
# 95: 1384
#
# 96: 1579
#
# 97: 1689
#
# 98: 1726
#
# 99: 1217
#
# 100: 1796
#
# 101: 1536
#
# 102: 1213
#
# 103: 1867
#
# 104: 1304
#
# 105: 2010
#
# 106: 1503
#
# 107: 1665
#
# 108: 1361
#
# 109: 814
#
# 110: 2007
#
# 111: 1430
#
# 112: 1625
#
# 113: 1958
#
# 114: 860
#
# 115: 1799
#
# 116: 1942
#
# 117: 1876
#
# 118: 1772
#
# 119: 1198
#
# 120: 1221
#
# 121: 1814
#
# 122: 1826
#
# 123: 1667
#
# 124: 1334
#
# 125: 1504
#
# 126: 1420
#
# 127: 1164
#
# 128: 1414
#
# 129: 1934
#
# 130: 1823
#
# 131: 1507
#
# 132: 1195
#
# 133: 21
#
# 134: 1752
#
# 135: 1472
#
# 136: 1196
#
# 137: 1558
#
# 138: 1322
#
# 139: 1927
#
# 140: 1556
#
# 141: 1922
#
# 142: 277
#
# 143: 1828
#
# 144: 1883
#
# 145: 1280
#
# 146: 1947
#
# 147: 1231
#
# 148: 1915
#
# 149: 1235
#
# 150: 1961
#
# 151: 1494
#
# 152: 1324
#
# 153: 2009
#
# 154: 1367
#
# 155: 1545
#
# 156: 1736
#
# 157: 1575
#
# 158: 1214
#
# 159: 1704
#
# 160: 1833
#
# 161: 1663
#
# 162: 1474
#
# 163: 1894
#
# 164: 1754
#
# 165: 1564
#
# 166: 1321
#
# 167: 1119
#
# 168: 1975
#
# 169: 1987
#
# 170: 1873
#
# 171: 1834
#
# 172: 1686
#
# 173: 1574
#
# 174: 1505
#
# 175: 1656
#
# 176: 1688
#
# 177: 1896
#
# 178: 1982
#
# 179: 1554
#
# 180: 1990
#
# 181: 1902
#
# 182: 1859
#
# 183: 1293
#
# 184: 1739
#
# 185: 1282
#
# 186: 1889
#
# 187: 1981
#
# 188: 1283
#
# 189: 1687
#
# 190: 1220
#
# 191: 1443
#
# 192: 1409
#
# 193: 1252
#
# 194: 1506
#
# 195: 1742
#
# 196: 1319
#
# 197: 1882
#
# 198: 951
#
# 199: 1849

# %%
def getInput(filename):
    tempList = []
    with open(filename, "r") as fp: 
        for i, line in enumerate(fp):
            tempList.append(int(line.rstrip('\n')))
    return tempList

def findTwoSumTo2020(numList):
    while len(numList) != 0:
        #print(numList[0])
        if 2020-numList[0] in numList:
            print(f"{numList[0]} + {2020-numList[0]} = 2020")
            return numList[0] * (2020-numList[0])
        else:
            numList.pop(0)
    else:
        return "no matches found"
    
def findThreeSumTo2020(numList):
    while len(numList) != 0:
        for i in numList[1:]:
            currentTotal = numList[0] + i
            if 2020-currentTotal in numList:
                print(f"{numList[0]} + {i} + {2020-currentTotal} = 2020")
                return numList[0] * i * (2020-currentTotal)
        numList.pop(0)
    else:
        return "no matches found"
        
#main routine
inputList = getInput("input.txt")
#print(findTwoSumTo2020(inputList))
#print(findThreeSumTo2020(inputList))

#would be nice to make this one routine which takes as input the number (eg. 2 or 3) to add to find 2020
# Out:
# 624 + + 277 + 1119 = 2020
# 193416912

# %%
def getInput(filename):
    with open(filename, "r") as fp:
        tempList = [int(line.strip()) for i, line in enumerate(fp)]
    fp.close()
    return tempList

def findTwoSumTo2020(numList):
    while len(numList) != 0:
        if 2020-numList[0] in numList:
            print(f"{numList[0]} + {2020-numList[0]} = 2020")
            return numList[0] * (2020-numList[0])
        else:
            numList.pop(0)
    else:
        return "no matches found"
    
def findThreeSumTo2020(numList):
    while len(numList) != 0:
        for i in numList[1:]:
            currentTotal = numList[0] + i
            if 2020-currentTotal in numList:
                print(f"{numList[0]} + {i} + {2020-currentTotal} = 2020")
                return numList[0] * i * (2020-currentTotal)
        numList.pop(0)
    else:
        return "no matches found"
        
#main routine
inputList = getInput("input.txt")
#print(findTwoSumTo2020(inputList))
print(findThreeSumTo2020(inputList))

#would be nice to make this one routine which takes as input the number (eg. 2 or 3) to add to find 2020
#also cause im editing the original list i can't run find2sum then find3sum
# Out:
# 200
# 1999 + 21 = 2020
# 41979
# 120
# no matches found

# %%
2020-1774
# Out:
# 246
